# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import numpy as np
from scipy.spatial.distance import cdist
from yellowbrick.cluster import SilhouetteVisualizer

# %% [markdown]
# # Now that we have imported libraries, let's load the dataset

# %%
df=pd.read_csv('Mall_Customers.csv')

# %% [markdown]
# # Let's visualise the dataset

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ### Let's test the moments of business decision making on this dataset

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# # Is our customer more likely to be a Man or a women?

# %%
sns.countplot(df['Gender'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # What's the distribution of Age, Income and Spending Score?

# %%
sns.boxplot(df['Age'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Annual Income (k$)'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Spending Score (1-100)'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # How does age fare with annual income and spending score?

# %%
sns.boxplot(df['Age'],df['Annual Income (k$)'])
plt.xticks(range(0,50,10))
plt.show()
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Age'],df['Spending Score (1-100)'])
plt.xticks(range(0,50,5))
plt.show()
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Is there any difference between genders on income or spending score?

# %%
sns.boxplot(df['Gender'],df['Annual Income (k$)'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Gender'],df['Spending Score (1-100)'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Is income connected with spending score?

# %%
plt.scatter(df['Annual Income (k$)'],df['Spending Score (1-100)'])
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %% [markdown]
# # Are older people more likely to have a higher spending score?

# %%
plt.scatter(df['Age'],df['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.show()

# %% [markdown]
# # Which age group tends to have higher income?

# %%
plt.scatter(df['Age'],df['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Annual income')
plt.show()

# %%
sns.boxplot(df['Gender'],df['Age'])
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df['Gender']=df['Gender'].map(dict(Male=1,Female=0))

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
df1=scaler.transform(df)

# %%
df=pd.DataFrame(df1,columns=df.columns)

# %% [markdown]
# ## How are columns correlated to each other?

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # Use the elbow method to decide how many clusters are required to define this dataset?

# %%
del df['CustomerID']

# %%
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {} 
K = range(1,7) 

for k in K: 

    kmeanModel = KMeans(n_clusters=k).fit(df) 
    kmeanModel.fit(df)
        
    distortions.append(sum(np.min(cdist(df, kmeanModel.cluster_centers_, 'euclidean'),axis=1)) / df.shape[0]) 
    inertias.append(kmeanModel.inertia_) 

    mapping1[k] = sum(np.min(cdist(df, kmeanModel.cluster_centers_, 'euclidean'),axis=1)) / df.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(K, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()

# %%
plt.plot(K, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %% [markdown]
# ### Use a different method to confirm and clarify the dimensions of the above method?

# %%
fig, ax = plt.subplots(2,2, figsize=(15,8))
for i in range(2,6):
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df)

# %% [markdown]
# ## Now split the data into two clusters and observe the patterns of the two methods

# %%
kmeanModel = KMeans(n_clusters=2).fit(df) 
kmeanModel.fit(df)
# Out:
# KMeans(n_clusters=2)

# %%
pred=kmeanModel.predict(df)

# %%
df=pd.read_csv('Mall_Customers.csv')
del df['CustomerID']

# %%
df['predicted']=pred

# %%
sns.countplot(pred)
# Out:
# /home/god/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_new=df[df['predicted']==0]
df_new1=df[df['predicted']==1]

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)',
#        'predicted'],
#       dtype='object')

# %%
df_new['Gender'].hist()
df_new1['Gender'].hist()
plt.legend(['cluster1','cluster2'])

# %% [markdown]
# # Age is determinant factor for division of clusters

# %%
df_new['Age'].hist()
df_new1['Age'].hist()
plt.legend(['cluster1','cluster2'])

# %%
df_new['Annual Income (k$)'].hist()
df_new1['Annual Income (k$)'].hist()
plt.legend(['cluster1','cluster2'])

# %% [markdown]
# ### Spending score is also a determinant factor for clustering

# %%
df_new['Spending Score (1-100)'].hist()
df_new1['Spending Score (1-100)'].hist()
plt.legend(['cluster1','cluster2'])

# %%
plt.scatter(df_new['Age'],df_new['Spending Score (1-100)'])
plt.scatter(df_new1['Age'],df_new1['Spending Score (1-100)'])
plt.legend(['cluster1','cluster2'])
plt.xlabel('age')
plt.ylabel('spending score')

# %%
plt.scatter(df_new['Age'],df_new['Annual Income (k$)'])
plt.scatter(df_new1['Age'],df_new1['Annual Income (k$)'])
plt.legend(['cluster1','cluster2'])
plt.xlabel('age')
plt.ylabel('annual income')
# Out:
# Text(0, 0.5, 'annual income')

# %%
plt.scatter(df_new['Spending Score (1-100)'],df_new['Annual Income (k$)'])
plt.scatter(df_new1['Spending Score (1-100)'],df_new1['Annual Income (k$)'])
plt.legend(['cluster1','cluster2'])
plt.xlabel('spending score')
plt.ylabel('annual income')
# Out:
# Text(0, 0.5, 'annual income')
